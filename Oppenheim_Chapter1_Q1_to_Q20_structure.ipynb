# %%
# Question 1
# computation structure goes here
pass

# %%
# Question 2
# computation structure goes here
pass

# %%
# Question 3
# computation structure goes here
pass

# %%
# Question 4
# computation structure goes here
pass

# %%
# Question 5
# computation structure goes here
pass

# %%
# Question 6
# computation structure goes here
pass

# %%
# Question 7
# computation structure goes here
pass

# %%
# Question 8
# computation structure goes here
pass

# %%
# Question 9
# computation structure goes here
pass

# %%
# Question 10
# computation structure goes here
pass

# %%
# Question 11
# computation structure goes here
pass

# %%
# Question 12
# computation structure goes here
pass

# %%
# Question 13
# computation structure goes here
pass

# %%
# Question 14
# computation structure goes here
pass

# %%
# Question 15
# computation structure goes here
pass

# %%
# Question 16
# computation structure goes here
pass

# %%
# Question 17
# computation structure goes here
pass

# %%
# Question 18
# computation structure goes here
pass

# %%
# Question 19
# computation structure goes here
pass

# %%
# Question 20
# computation structure goes here
pass
