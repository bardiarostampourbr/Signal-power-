# %%
import numpy as np
from scipy import signal
import sympy as sp

# %%
# Question 1
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 2
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 3
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 4
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 5
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 6
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 7
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 8
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 9
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 10
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 11
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 12
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 13
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 14
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass

# %%
# Question 15
n = sp.symbols('n', integer=True)
z = sp.symbols('z')
## define signal x[n] (placeholder)
# x = lambda k: ...
# or x = np.array([...])

## Convolution structure
# h = lambda k: ...
# y = np.convolve(x, h)

## Difference equation solver structure
# a = [1, ...]
# b = [ ... ]
# y = signal.lfilter(b, a, x)

## Z-transform / DTFT structures
# X_z = sp.summation(x(n)*z**(-n), (n, -sp.oo, sp.oo))  # placeholder
# X_dtft = np.fft.fft(x, 512)

## Pole-zero / stability analysis structure
# zpk = signal.tf2zpk(b, a)

pass
